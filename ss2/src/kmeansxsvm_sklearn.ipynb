# %% [markdown]
# # Scikit-Learn

# %% [markdown]
# # 1. Data

# %%
# Load Data
import numpy as np 

def load_data(path = "/Users/charles/MLGT/SS2/Data/"):
    # Get data from each line with label, doc_id, index & tfidf of its vocab
    def sparse_to_dense(sparse_r_d, vocab_size):
        # Init list size vocal size to store vocal 
        r_d = [0.0 for _ in range(vocab_size)]
            
        # Split space & : in context data of each line 
        # Get index (id vocal of each line) & tfidfs
        indices_and_tfidfs = sparse_r_d.split()
        for index_and_tfidf in indices_and_tfidfs:
            index = int(index_and_tfidf.split(':')[0])
            tfidf = float(index_and_tfidf.split(':')[1])
            r_d[index] = tfidf
        return np.array(r_d)    
                
    # Open file (newsgroup, id, context)
    with open(path + "data_tf_idf.txt") as f:
        data_lines = f.read().splitlines()
    # Get size file vocal TF-IDF
    with open(path + "words_idfs.txt") as f:
        vocab_size = len(f.read().splitlines())

    # Member store info of data points: tf_idf, news group, file name of text d
    data, labels = [], []
    # Iterating sequence of pairs with counter
    for data_id, d in enumerate(data_lines):
        features = d.split('<fff>')
        label, doc_id = int(features[0]), int(features[1])
        r_d = sparse_to_dense(sparse_r_d=features[2], vocab_size=vocab_size)

        # Append data & labels
        data.append(r_d)
        labels.append(label)
    return data, np.array(labels)

# %%
# Load data
X, y = load_data()

# Split Data
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=42)

# Use csr_matrix to create a sparse matrix with efficient row slicing
# Improve time to computing
from scipy.sparse import csr_matrix
X = csr_matrix(X)

# %% [markdown]
# # 2. Accuracy

# %%
# Loss Function
def compute_accuracy(predicted_y, expected_y):
    # Check boolean True = 1, False = 0 
    matches = np.equal(predicted_y, expected_y)
    accuracy = np.sum(matches.astype(float)) / len(expected_y)
    return accuracy

# %% [markdown]
# # 3. KMeans

# %%
from sklearn.cluster import KMeans
# Training to collecting parameter
kmeans = KMeans(random_state=42,             # seed value
                tol = 1e-3,                  # threshold 
                n_init= 5).fit(X_train)         # number of times running with differently init centroid

# %%
predicted_y_kmeans = kmeans.predict(X_test)

# Accuracy
accuracy_kmeans = compute_accuracy(predicted_y = predicted_y_kmeans, expected_y = y_test)
accuracy_kmeans
# Out:
# 0.03353140916808149

# %% [markdown]
# # 4. SVM

# %% [markdown]
# ## 4.1. Linear SVMs

# %%
# Load data
X, y = load_data()

# Use csr_matrix to create a sparse matrix with efficient row slicing
# Improve time to computing
from scipy.sparse import csr_matrix
X = csr_matrix(X)

# Split Data
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=78)

# %%
from sklearn.svm import LinearSVC

classifier = LinearSVC(
    C=10.0,             # penalty coeff
    tol=0.001,          # tolerance for stopping criteria
    verbose=True        # whether prints out logs or not
).fit(X_train, y_train)

predicted_y_svm = classifier.predict(X_test)
accuracy = compute_accuracy(predicted_y=predicted_y_svm, expected_y=y_test)
accuracy
# Out:
# [LibLinear]...........*.*
# optimization finished, #iter = 122
# Objective value = -476.958797
# nSV = 1350
# ..........................*..*
# optimization finished, #iter = 288
# Objective value = -928.932852
# nSV = 1876
# ............................*.......***
# optimization finished, #iter = 359
# Objective value = -1027.136604
# nSV = 1830
# .........................*
# optimization finished, #iter = 253
# Objective value = -1255.974334
# nSV = 2107
# .......................***.
# optimization finished, #iter = 240
# Objective value = -813.172786
# nSV = 1844
# ............................***
# optimization finished, #iter = 285
# Objective value = -677.013917
# nSV = 1745
# .........................*
# optimization finished, #iter = 253
# Objective value = -856.913884
# nSV = 1829
# ....................*.*
# optimization finished, #iter = 215
# Objective value = -596.689673
# nSV = 1822
# ................*.**
# optimization finished, #iter = 174
# Objective value = -384.038738
# nSV = 1604
# ...........*.
# optimization finished, #iter = 120
# Objective value = -430.650257
# nSV = 1606
# .....................**
# optimization finished, #iter = 214
# Objective value = -324.562361
# nSV = 1280
# .................*
# optimization finished, #iter = 179
# Objective value = -354.487015
# nSV = 1483
# ........................*
# optimization finished, #iter = 247
# Objective value = -959.220588
# nSV = 2116
# .......................*
# optimization finished, #iter = 236
# Objective value = -508.255948
# nSV = 1851
# ........................*
# optimization finished, #iter = 247
# Objective value = -408.293854
# nSV = 1552
# ........................*
# optimization finished, #iter = 247
# Objective value = -514.414153
# nSV = 1691
# .....................*.*
# optimization finished, #iter = 225
# Objective value = -524.968716
# nSV = 1590
# ............*
# optimization finished, #iter = 121
# Objective value = -254.687326
# nSV = 1350
# ....................*..*
# optimization finished, #iter = 229
# Objective value = -568.544785
# nSV = 1730
# ........................*..*
# optimization finished, #iter = 262
# Objective value = -697.627234
# nSV = 1723
# 0.9142614601018676

# %% [markdown]
# ## 4.2 Kernel SVMs

# %%
# Load data
X, y = load_data()

# Use csr_matrix to create a sparse matrix with efficient row slicing
# Improve time to computing
from scipy.sparse import csr_matrix
X = csr_matrix(X)

# Split Data
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=79)

# %%
from sklearn.svm import SVC

classifier_ker = SVC(
    C=50.0,             # penalty coeff
    kernel="rbf",       
    gamma=0.1,
    tol=0.001,          # tolerance for stopping criteria
    verbose=True        # whether prints out logs or not
).fit(X_train, y_train)

predicted_y_svc = classifier_ker.predict(X_test)
accuracy = compute_accuracy(predicted_y=predicted_y_svc, expected_y=y_test)
accuracy
# Out:
# [LibSVM]*.*
# optimization finished, #iter = 1259
# obj = -588.837672, rho = 0.325817
# nSV = 551, nBSV = 0
# *.*
# optimization finished, #iter = 1164
# obj = -506.301100, rho = 0.229902
# nSV = 513, nBSV = 0
# *.*
# optimization finished, #iter = 1275
# obj = -533.746849, rho = 0.271207
# nSV = 536, nBSV = 0
# *.*
# optimization finished, #iter = 1227
# obj = -535.910795, rho = 0.266039
# nSV = 532, nBSV = 0
# *.*
# optimization finished, #iter = 1208
# obj = -519.954914, rho = 0.244365
# nSV = 530, nBSV = 0
# *.*
# optimization finished, #iter = 1213
# obj = -548.006673, rho = 0.363611
# nSV = 551, nBSV = 0
# *.*
# optimization finished, #iter = 1278
# obj = -553.751935, rho = 0.279694
# nSV = 551, nBSV = 0
# *.*
# optimization finished, #iter = 1322
# obj = -521.020984, rho = 0.184302
# nSV = 540, nBSV = 0
# *.*
# optimization finished, #iter = 1277
# obj = -536.057834, rho = 0.239926
# nSV = 526, nBSV = 0
# *.*
# optimization finished, #iter = 1060
# obj = -449.264274, rho = 0.094582
# nSV = 466, nBSV = 0
# *.*
# optimization finished, #iter = 1144
# obj = -541.255968, rho = 0.061608
# nSV = 487, nBSV = 0
# .*
# optimization finished, #iter = 1463
# obj = -600.957553, rho = 0.413598
# nSV = 616, nBSV = 0
# *.*
# optimization finished, #iter = 1452
# obj = -673.313083, rho = 0.386471
# nSV = 614, nBSV = 0
# *.*
# optimization finished, #iter = 1259
# obj = -588.733535, rho = 0.186281
# nSV = 529, nBSV = 0
# .*
# optimization finished, #iter = 1796
# obj = -1006.758600, rho = 0.232497
# nSV = 639, nBSV = 0
# *.*
# optimization finished, #iter = 1253
# obj = -598.718888, rho = 0.114908
# nSV = 506, nBSV = 0
# *.*
# optimization finished, #iter = 1261
# obj = -576.900170, rho = 0.018646
# nSV = 501, nBSV = 0
# *.*
# optimization finished, #iter = 1373
# obj = -683.916399, rho = 0.187992
# nSV = 558, nBSV = 0
# .*
# optimization finished, #iter = 1951
# obj = -1694.510282, rho = 0.225148
# nSV = 630, nBSV = 0
# .*.*
# optimization finished, #iter = 2050
# obj = -1924.398993, rho = -0.113670
# nSV = 739, nBSV = 9
# .*.*
# optimization finished, #iter = 2159
# obj = -1685.891500, rho = -0.049776
# nSV = 769, nBSV = 4
# .*
# optimization finished, #iter = 1838
# obj = -1328.057768, rho = -0.050837
# nSV = 709, nBSV = 2
# .*.*
# optimization finished, #iter = 2030
# obj = -1898.245256, rho = -0.118014
# nSV = 752, nBSV = 8
# .*
# optimization finished, #iter = 1701
# obj = -1202.093751, rho = 0.028344
# nSV = 711, nBSV = 1
# .*
# optimization finished, #iter = 1588
# obj = -835.924435, rho = -0.089102
# nSV = 654, nBSV = 0
# *.*
# optimization finished, #iter = 1468
# obj = -734.008587, rho = -0.175953
# nSV = 621, nBSV = 0
# *.*
# optimization finished, #iter = 1414
# obj = -748.206503, rho = -0.093441
# nSV = 626, nBSV = 0
# *.*
# optimization finished, #iter = 1242
# obj = -612.195855, rho = -0.228313
# nSV = 543, nBSV = 0
# *.*
# optimization finished, #iter = 1447
# obj = -814.293163, rho = -0.365399
# nSV = 603, nBSV = 0
# .*.*
# optimization finished, #iter = 2050
# obj = -1412.628013, rho = 0.028270
# nSV = 772, nBSV = 1
# .*
# optimization finished, #iter = 1633
# obj = -1009.124873, rho = 0.005670
# nSV = 669, nBSV = 0
# .*
# optimization finished, #iter = 1585
# obj = -888.779932, rho = -0.209313
# nSV = 645, nBSV = 0
# *.*
# optimization finished, #iter = 1299
# obj = -697.862517, rho = -0.228294
# nSV = 593, nBSV = 0
# *.*
# optimization finished, #iter = 1269
# obj = -694.636573, rho = -0.278364
# nSV = 573, nBSV = 1
# *.*
# optimization finished, #iter = 1139
# obj = -638.931885, rho = -0.278983
# nSV = 519, nBSV = 1
# *.*
# optimization finished, #iter = 1342
# obj = -710.638676, rho = -0.177915
# nSV = 587, nBSV = 0
# *.*
# optimization finished, #iter = 1234
# obj = -714.197702, rho = -0.231873
# nSV = 558, nBSV = 1
# .*.*
# optimization finished, #iter = 2308
# obj = -1990.875498, rho = 0.104748
# nSV = 774, nBSV = 3
# .*
# optimization finished, #iter = 1744
# obj = -1275.740727, rho = 0.016096
# nSV = 664, nBSV = 3
# .*.*
# optimization finished, #iter = 2067
# obj = -1825.969627, rho = -0.131975
# nSV = 741, nBSV = 7
# .*
# optimization finished, #iter = 1564
# obj = -1038.910248, rho = 0.109576
# nSV = 650, nBSV = 0
# *.*
# optimization finished, #iter = 1352
# obj = -729.073181, rho = 0.030558
# nSV = 598, nBSV = 0
# *.*
# optimization finished, #iter = 1313
# obj = -653.422322, rho = -0.061896
# nSV = 563, nBSV = 0
# *.*
# optimization finished, #iter = 1282
# obj = -667.707209, rho = 0.033279
# nSV = 559, nBSV = 0
# *.*
# optimization finished, #iter = 1129
# obj = -548.581144, rho = -0.113577
# nSV = 510, nBSV = 0
# *.*
# optimization finished, #iter = 1331
# obj = -741.129626, rho = -0.249913
# nSV = 550, nBSV = 1
# .*
# optimization finished, #iter = 1805
# obj = -1212.435931, rho = 0.136027
# nSV = 692, nBSV = 1
# *.*
# optimization finished, #iter = 1444
# obj = -816.554123, rho = 0.112839
# nSV = 629, nBSV = 0
# *.*
# optimization finished, #iter = 1271
# obj = -684.212481, rho = -0.068817
# nSV = 561, nBSV = 0
# *.*
# optimization finished, #iter = 1146
# obj = -620.582182, rho = -0.146699
# nSV = 529, nBSV = 0
# *.*
# optimization finished, #iter = 1155
# obj = -719.339876, rho = -0.162586
# nSV = 521, nBSV = 2
# *.*
# optimization finished, #iter = 1054
# obj = -555.622798, rho = -0.187244
# nSV = 490, nBSV = 1
# *.*
# optimization finished, #iter = 1185
# obj = -631.707606, rho = -0.072633
# nSV = 542, nBSV = 0
# *.*
# optimization finished, #iter = 1120
# obj = -649.917130, rho = -0.149889
# nSV = 504, nBSV = 2
# .*.*
# optimization finished, #iter = 2434
# obj = -2014.410022, rho = -0.079788
# nSV = 781, nBSV = 3
# .*
# optimization finished, #iter = 1695
# obj = -1147.013774, rho = -0.050221
# nSV = 673, nBSV = 2
# .*.*
# optimization finished, #iter = 2210
# obj = -1656.307043, rho = 0.016288
# nSV = 782, nBSV = 0
# .*
# optimization finished, #iter = 1514
# obj = -849.682359, rho = -0.013572
# nSV = 640, nBSV = 0
# .*
# optimization finished, #iter = 1512
# obj = -715.346396, rho = -0.110304
# nSV = 617, nBSV = 0
# *.*
# optimization finished, #iter = 1393
# obj = -720.118107, rho = 0.000639
# nSV = 585, nBSV = 0
# *.*
# optimization finished, #iter = 1218
# obj = -619.802488, rho = -0.140827
# nSV = 528, nBSV = 0
# *.*
# optimization finished, #iter = 1394
# obj = -749.938930, rho = -0.309871
# nSV = 575, nBSV = 0
# .*.*
# optimization finished, #iter = 2364
# obj = -1794.961127, rho = 0.139124
# nSV = 815, nBSV = 3
# .*
# optimization finished, #iter = 1488
# obj = -905.938794, rho = 0.076774
# nSV = 638, nBSV = 0
# *.*
# optimization finished, #iter = 1452
# obj = -719.072341, rho = -0.121015
# nSV = 599, nBSV = 0
# *.*
# optimization finished, #iter = 1222
# obj = -618.718634, rho = -0.156910
# nSV = 567, nBSV = 0
# *.*
# optimization finished, #iter = 1274
# obj = -666.761148, rho = -0.208261
# nSV = 552, nBSV = 2
# *.*
# optimization finished, #iter = 1145
# obj = -580.931207, rho = -0.211370
# nSV = 524, nBSV = 2
# *.*
# optimization finished, #iter = 1312
# obj = -661.022927, rho = -0.121438
# nSV = 566, nBSV = 0
# *.*
# optimization finished, #iter = 1257
# obj = -656.090968, rho = -0.173396
# nSV = 540, nBSV = 1
# .*
# optimization finished, #iter = 1586
# obj = -1062.026259, rho = -0.030141
# nSV = 639, nBSV = 2
# .*.*
# optimization finished, #iter = 2009
# obj = -1421.594161, rho = 0.110278
# nSV = 735, nBSV = 0
# .*
# optimization finished, #iter = 1564
# obj = -838.151132, rho = 0.015260
# nSV = 638, nBSV = 0
# *.*
# optimization finished, #iter = 1482
# obj = -733.190898, rho = -0.092973
# nSV = 601, nBSV = 0
# *.*
# optimization finished, #iter = 1482
# obj = -723.564527, rho = -0.006947
# nSV = 597, nBSV = 0
# *.*
# optimization finished, #iter = 1124
# obj = -611.110993, rho = -0.162973
# nSV = 509, nBSV = 0
# *.*
# optimization finished, #iter = 1275
# obj = -717.330782, rho = -0.286758
# nSV = 548, nBSV = 0
# .*.*
# optimization finished, #iter = 2110
# obj = -1508.308875, rho = 0.164033
# nSV = 770, nBSV = 1
# .*
# optimization finished, #iter = 1565
# obj = -906.899486, rho = 0.099434
# nSV = 654, nBSV = 0
# *.*
# optimization finished, #iter = 1416
# obj = -746.034449, rho = -0.103780
# nSV = 593, nBSV = 0
# *.*
# optimization finished, #iter = 1210
# obj = -628.723492, rho = -0.163155
# nSV = 544, nBSV = 0
# *.*
# optimization finished, #iter = 1181
# obj = -683.142628, rho = -0.203341
# nSV = 540, nBSV = 2
# *.*
# optimization finished, #iter = 1134
# obj = -585.468651, rho = -0.231152
# nSV = 504, nBSV = 1
# *.*
# optimization finished, #iter = 1223
# obj = -694.216343, rho = -0.104687
# nSV = 549, nBSV = 0
# *.*
# optimization finished, #iter = 1199
# obj = -659.816185, rho = -0.183991
# nSV = 538, nBSV = 2
# .*
# optimization finished, #iter = 1564
# obj = -873.395568, rho = 0.120661
# nSV = 667, nBSV = 0
# *.*
# optimization finished, #iter = 1399
# obj = -729.668444, rho = 0.011365
# nSV = 607, nBSV = 0
# *.*
# optimization finished, #iter = 1388
# obj = -669.828873, rho = -0.072251
# nSV = 583, nBSV = 0
# *.*
# optimization finished, #iter = 1321
# obj = -682.152374, rho = 0.011825
# nSV = 567, nBSV = 0
# *.*
# optimization finished, #iter = 1102
# obj = -561.952927, rho = -0.133099
# nSV = 501, nBSV = 0
# *.*
# optimization finished, #iter = 1303
# obj = -764.435949, rho = -0.250648
# nSV = 555, nBSV = 1
# .*
# optimization finished, #iter = 1752
# obj = -1102.827476, rho = 0.159982
# nSV = 711, nBSV = 1
# *.*
# optimization finished, #iter = 1423
# obj = -839.347422, rho = 0.083007
# nSV = 631, nBSV = 0
# *.*
# optimization finished, #iter = 1326
# obj = -776.344694, rho = -0.113961
# nSV = 571, nBSV = 0
# *.*
# optimization finished, #iter = 1170
# obj = -609.556332, rho = -0.137701
# nSV = 534, nBSV = 0
# *.*
# optimization finished, #iter = 1112
# obj = -700.253919, rho = -0.168965
# nSV = 538, nBSV = 3
# *.*
# optimization finished, #iter = 1118
# obj = -567.114030, rho = -0.212253
# nSV = 494, nBSV = 1
# *.*
# optimization finished, #iter = 1183
# obj = -619.418240, rho = -0.093352
# nSV = 550, nBSV = 0
# *.*
# optimization finished, #iter = 1176
# obj = -636.696815, rho = -0.156249
# nSV = 527, nBSV = 2
# .*
# optimization finished, #iter = 1732
# obj = -1195.226430, rho = -0.084234
# nSV = 703, nBSV = 1
# .*
# optimization finished, #iter = 1568
# obj = -879.847742, rho = -0.237460
# nSV = 646, nBSV = 0
# .*
# optimization finished, #iter = 1516
# obj = -862.524225, rho = -0.122535
# nSV = 635, nBSV = 0
# *.*
# optimization finished, #iter = 1286
# obj = -717.182434, rho = -0.243709
# nSV = 560, nBSV = 0
# *.*
# optimization finished, #iter = 1254
# obj = -703.068838, rho = -0.375242
# nSV = 556, nBSV = 0
# .*
# optimization finished, #iter = 1999
# obj = -1699.713377, rho = 0.083605
# nSV = 780, nBSV = 5
# .*
# optimization finished, #iter = 1545
# obj = -954.682719, rho = -0.044644
# nSV = 664, nBSV = 0
# *.*
# optimization finished, #iter = 1437
# obj = -791.769103, rho = -0.239974
# nSV = 613, nBSV = 0
# *.*
# optimization finished, #iter = 1235
# obj = -638.780311, rho = -0.217714
# nSV = 588, nBSV = 0
# *.*
# optimization finished, #iter = 1297
# obj = -683.099501, rho = -0.295898
# nSV = 583, nBSV = 0
# *.*
# optimization finished, #iter = 1202
# obj = -578.951670, rho = -0.295558
# nSV = 556, nBSV = 0
# *.*
# optimization finished, #iter = 1309
# obj = -742.783293, rho = -0.233534
# nSV = 602, nBSV = 0
# *.*
# optimization finished, #iter = 1228
# obj = -652.177458, rho = -0.253321
# nSV = 566, nBSV = 0
# .*
# optimization finished, #iter = 1765
# obj = -1058.328504, rho = -0.145567
# nSV = 652, nBSV = 0
# .*
# optimization finished, #iter = 1518
# obj = -762.032330, rho = -0.017515
# nSV = 614, nBSV = 0
# *.*
# optimization finished, #iter = 1275
# obj = -605.962653, rho = -0.167223
# nSV = 533, nBSV = 0
# *.*
# optimization finished, #iter = 1310
# obj = -619.019241, rho = -0.229105
# nSV = 563, nBSV = 0
# .*
# optimization finished, #iter = 1905
# obj = -1152.054077, rho = 0.197885
# nSV = 724, nBSV = 0
# .*
# optimization finished, #iter = 1571
# obj = -849.825331, rho = 0.085319
# nSV = 657, nBSV = 0
# *.*
# optimization finished, #iter = 1480
# obj = -722.947504, rho = -0.086951
# nSV = 611, nBSV = 0
# *.*
# optimization finished, #iter = 1314
# obj = -609.539791, rho = -0.125026
# nSV = 577, nBSV = 0
# *.*
# optimization finished, #iter = 1365
# obj = -709.494244, rho = -0.191088
# nSV = 576, nBSV = 0
# *.*
# optimization finished, #iter = 1269
# obj = -553.447380, rho = -0.220527
# nSV = 540, nBSV = 0
# *.*
# optimization finished, #iter = 1417
# obj = -764.720676, rho = -0.115492
# nSV = 603, nBSV = 0
# *.*
# optimization finished, #iter = 1309
# obj = -639.609640, rho = -0.152620
# nSV = 556, nBSV = 0
# *.*
# optimization finished, #iter = 1458
# obj = -700.156516, rho = 0.076296
# nSV = 593, nBSV = 0
# *.*
# optimization finished, #iter = 1317
# obj = -567.485994, rho = -0.066622
# nSV = 542, nBSV = 0
# *.*
# optimization finished, #iter = 1300
# obj = -582.131675, rho = -0.137765
# nSV = 532, nBSV = 0
# .*
# optimization finished, #iter = 1844
# obj = -866.855153, rho = 0.271832
# nSV = 709, nBSV = 0
# .*
# optimization finished, #iter = 1527
# obj = -766.314639, rho = 0.182607
# nSV = 637, nBSV = 0
# *.*
# optimization finished, #iter = 1466
# obj = -651.575734, rho = 0.012704
# nSV = 599, nBSV = 0
# *.*
# optimization finished, #iter = 1312
# obj = -568.489817, rho = -0.042275
# nSV = 557, nBSV = 0
# *.*
# optimization finished, #iter = 1422
# obj = -634.377479, rho = -0.113601
# nSV = 563, nBSV = 0
# *.*
# optimization finished, #iter = 1260
# obj = -508.445505, rho = -0.140027
# nSV = 527, nBSV = 0
# *.*
# optimization finished, #iter = 1370
# obj = -681.295862, rho = -0.007315
# nSV = 575, nBSV = 0
# *.*
# optimization finished, #iter = 1323
# obj = -595.420772, rho = -0.074232
# nSV = 545, nBSV = 0
# .*
# optimization finished, #iter = 1664
# obj = -976.386127, rho = -0.185019
# nSV = 610, nBSV = 0
# *.*
# optimization finished, #iter = 1281
# obj = -581.028467, rho = -0.215787
# nSV = 522, nBSV = 0
# .*
# optimization finished, #iter = 1618
# obj = -818.057319, rho = 0.157252
# nSV = 660, nBSV = 0
# .*
# optimization finished, #iter = 1573
# obj = -813.672232, rho = 0.097592
# nSV = 628, nBSV = 0
# *.*
# optimization finished, #iter = 1423
# obj = -658.331903, rho = -0.078858
# nSV = 578, nBSV = 0
# *.*
# optimization finished, #iter = 1240
# obj = -604.437924, rho = -0.116848
# nSV = 550, nBSV = 0
# *.*
# optimization finished, #iter = 1289
# obj = -631.317659, rho = -0.182116
# nSV = 545, nBSV = 0
# *.*
# optimization finished, #iter = 1299
# obj = -535.124089, rho = -0.206928
# nSV = 527, nBSV = 0
# *.*
# optimization finished, #iter = 1363
# obj = -708.171534, rho = -0.087820
# nSV = 570, nBSV = 0
# *.*
# optimization finished, #iter = 1246
# obj = -609.595551, rho = -0.142383
# nSV = 528, nBSV = 0
# *
# optimization finished, #iter = 990
# obj = -489.057194, rho = -0.058552
# nSV = 464, nBSV = 0
# *.*
# optimization finished, #iter = 1394
# obj = -668.766969, rho = 0.291153
# nSV = 595, nBSV = 0
# *.*
# optimization finished, #iter = 1312
# obj = -627.469469, rho = 0.246769
# nSV = 563, nBSV = 0
# *.*
# optimization finished, #iter = 1165
# obj = -548.769053, rho = 0.074509
# nSV = 513, nBSV = 0
# *.*
# optimization finished, #iter = 1107
# obj = -494.491067, rho = 0.037491
# nSV = 493, nBSV = 0
# *.*
# optimization finished, #iter = 1054
# obj = -522.093103, rho = -0.019968
# nSV = 487, nBSV = 0
# *.*
# optimization finished, #iter = 1039
# obj = -467.018477, rho = -0.063296
# nSV = 455, nBSV = 0
# *.*
# optimization finished, #iter = 1175
# obj = -572.636340, rho = 0.056329
# nSV = 490, nBSV = 0
# *.*
# optimization finished, #iter = 1077
# obj = -516.376603, rho = 0.006891
# nSV = 479, nBSV = 0
# .*
# optimization finished, #iter = 1637
# obj = -881.572594, rho = 0.453199
# nSV = 664, nBSV = 0
# *.*
# optimization finished, #iter = 1349
# obj = -716.698486, rho = 0.341417
# nSV = 578, nBSV = 0
# *.*
# optimization finished, #iter = 1227
# obj = -655.267772, rho = 0.155188
# nSV = 534, nBSV = 0
# *.*
# optimization finished, #iter = 1105
# obj = -551.595120, rho = 0.110176
# nSV = 499, nBSV = 0
# *.*
# optimization finished, #iter = 1318
# obj = -853.450862, rho = 0.059448
# nSV = 524, nBSV = 1
# *.*
# optimization finished, #iter = 1077
# obj = -518.031132, rho = 0.004877
# nSV = 476, nBSV = 0
# *.*
# optimization finished, #iter = 1457
# obj = -754.183302, rho = 0.179656
# nSV = 590, nBSV = 0
# *.*
# optimization finished, #iter = 1140
# obj = -592.596959, rho = 0.098691
# nSV = 494, nBSV = 0
# .*
# optimization finished, #iter = 1874
# obj = -1149.213008, rho = -0.086065
# nSV = 735, nBSV = 0
# .*
# optimization finished, #iter = 1793
# obj = -959.112850, rho = -0.289160
# nSV = 700, nBSV = 0
# *.*
# optimization finished, #iter = 1469
# obj = -719.994334, rho = -0.280176
# nSV = 643, nBSV = 0
# .*
# optimization finished, #iter = 1518
# obj = -756.904424, rho = -0.334037
# nSV = 643, nBSV = 1
# *.*
# optimization finished, #iter = 1383
# obj = -641.918379, rho = -0.340531
# nSV = 592, nBSV = 1
# .*
# optimization finished, #iter = 1566
# obj = -781.801707, rho = -0.281236
# nSV = 646, nBSV = 0
# *.*
# optimization finished, #iter = 1404
# obj = -732.550322, rho = -0.311419
# nSV = 596, nBSV = 1
# .*
# optimization finished, #iter = 1533
# obj = -861.950658, rho = -0.181572
# nSV = 628, nBSV = 0
# *.*
# optimization finished, #iter = 1392
# obj = -776.051229, rho = -0.233407
# nSV = 615, nBSV = 0
# *.*
# optimization finished, #iter = 1425
# obj = -751.183959, rho = -0.296178
# nSV = 602, nBSV = 0
# *.*
# optimization finished, #iter = 1366
# obj = -626.655981, rho = -0.314752
# nSV = 579, nBSV = 0
# .*
# optimization finished, #iter = 1656
# obj = -881.287188, rho = -0.216522
# nSV = 657, nBSV = 0
# *.*
# optimization finished, #iter = 1418
# obj = -789.569931, rho = -0.255524
# nSV = 608, nBSV = 0
# *.*
# optimization finished, #iter = 1226
# obj = -617.359257, rho = -0.023974
# nSV = 541, nBSV = 0
# *.*
# optimization finished, #iter = 1249
# obj = -693.675165, rho = -0.090987
# nSV = 522, nBSV = 2
# *.*
# optimization finished, #iter = 1109
# obj = -551.448835, rho = -0.136793
# nSV = 500, nBSV = 0
# *.*
# optimization finished, #iter = 1349
# obj = -724.886838, rho = -0.018003
# nSV = 578, nBSV = 0
# *.*
# optimization finished, #iter = 1256
# obj = -728.023149, rho = -0.064633
# nSV = 535, nBSV = 2
# *.*
# optimization finished, #iter = 1223
# obj = -615.042588, rho = -0.060607
# nSV = 525, nBSV = 0
# *.*
# optimization finished, #iter = 1173
# obj = -648.426050, rho = -0.115304
# nSV = 496, nBSV = 0
# *.*
# optimization finished, #iter = 1348
# obj = -715.899660, rho = 0.023532
# nSV = 577, nBSV = 0
# .*.*
# optimization finished, #iter = 2005
# obj = -1491.645402, rho = -0.116029
# nSV = 710, nBSV = 2
# *.*
# optimization finished, #iter = 1202
# obj = -632.717998, rho = -0.062566
# nSV = 511, nBSV = 1
# .*
# optimization finished, #iter = 1940
# obj = -1383.609161, rho = 0.113137
# nSV = 679, nBSV = 2
# *.*
# optimization finished, #iter = 1321
# obj = -881.681618, rho = 0.020578
# nSV = 541, nBSV = 1
# *.*
# optimization finished, #iter = 1367
# obj = -753.080687, rho = 0.188662
# nSV = 564, nBSV = 0
# *.*
# optimization finished, #iter = 1199
# obj = -660.320049, rho = 0.121070
# nSV = 515, nBSV = 0
# *.*
# optimization finished, #iter = 1414
# obj = -947.481189, rho = -0.050072
# nSV = 566, nBSV = 0
# Total nSV = 10136
# 0.9044991511035654
